# %% [markdown]
# # Ejecución del script de la app
# Este notebook permite ejecutar y analizar el script `app/app.py` en celdas separadas para facilitar su comprensión y depuración.

# %% [markdown]
# ## 1. Importar librerías necesarias
# Importamos las librerías requeridas para el script de la app.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# Agregar la raíz del proyecto al sys.path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

from src.models.gestion_stock import GestorStock, EOQResult

# %% [markdown]
# ## 2. Definir la función principal
# definimos la función principal que contendrá la lógica del script de la app.

# %%
# Debido a que Streamlit no se ejecuta en notebooks, solo mostramos la estructura principal
def main():
    print("Este script está diseñado para ejecutarse con Streamlit.")
    # Aquí iría la lógica de la app, pero en notebook no se puede mostrar la interfaz interactiva
    # Puedes importar y probar funciones individuales aquí si lo deseas

main()
# Out:
# Este script está diseñado para ejecutarse con Streamlit.

# %% [markdown]
# ## 3. Ejecutar el script y mostrar resultados
# Ejecutamos la función principal para mostrar el mensaje de aviso y, si se desea, se pueden probar funciones específicas del módulo `GestorStock` aquí.

# %%
# Aquí puedes probar funciones específicas, por ejemplo:
# resultado = GestorStock.eoq_clasico(D=1000, C1=2.5, C3=10, C4=5, lead_time=5)
# print(resultado)

# Por defecto, solo ejecutamos main()
main()
# Out:
# Este script está diseñado para ejecutarse con Streamlit.
